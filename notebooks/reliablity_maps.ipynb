# %%
import sys
sys.path.append("..")
from ProbabilisticParcellation.util import *
from Functional_Fusion.dataset import * 
import matplotlib.pyplot as plt

base_dir = '/Volumes/diedrichsen_data$/data/FunctionalFusion'
if not Path(base_dir).exists():
    base_dir = '/srv/diedrichsen/data/FunctionalFusion'

# %% [markdown]
# Reliability in each sessions for voxel-wise maps
# We want to see here which parts of the cerebellum we get information
# from from different data sets
#
# Reliability maps are shown at the same scale for comparision

# %% [markdown]
# ## MDTB dataset

# %%
rel,sess = reliability_maps(base_dir,'Mdtb')
plt.figure(figsize=(14,8))
plot_multi_flat(rel,'MNISymC3',
                    grid=(1,2),
                    dtype='func',
                    cscale=[-0.3,0.7],
                    colorbar=True,
                    titles=sess)
# Out:
# /Users/jdiedrichsen/Python/Functional_Fusion/dataset.py:151: RuntimeWarning: invalid value encountered in true_divide
#   r[s,pn,:] = nansum(X1*X2,axis=0)/ \
# /Users/jdiedrichsen/Python/Functional_Fusion/dataset.py:216: RuntimeWarning: Mean of empty slice
#   Rel[i,:] = np.nanmean(np.nanmean(r,axis=0),axis=0)
# /Users/jdiedrichsen/Python/SUITPy/SUITPy/flatmap.py:232: RuntimeWarning: Mean of empty slice
#   mapped_data[:,index[v]:index[v+1]] = np.nanmean(data,axis=0)
# /Users/jdiedrichsen/Python/SUITPy/SUITPy/flatmap.py:232: RuntimeWarning: Mean of empty slice
#   mapped_data[:,index[v]:index[v+1]] = np.nanmean(data,axis=0)

# %% [markdown]
# ## Pontine dataset

# %%
rel,sess = reliability_maps(base_dir,'Pontine')
plt.figure(figsize=(9,8))
plot_multi_flat(rel,'MNISymC3',
                    grid=(1,1),
                    dtype='func',
                    cscale=[-0.3,0.7],
                    colorbar=False,
                    titles=sess)

# %% [markdown]
# ## Nishimoto dataset

# %%
rel,sess = reliability_maps(base_dir,'Nishimoto')
plt.figure(figsize=(14,8))
plot_multi_flat(rel,'MNISymC3',
                    grid=(1,2),
                    dtype='func',
                    cscale=[-0.3,0.7],
                    colorbar=False,
                    titles=sess)
# Out:
# /Users/jdiedrichsen/Python/Functional_Fusion/dataset.py:151: RuntimeWarning: invalid value encountered in true_divide
#   r[s,pn,:] = nansum(X1*X2,axis=0)/ \

# %% [markdown]
# ## IBC dataset

# %%
rel,sess = reliability_maps(base_dir,'IBC')
# Out:
# /Users/jdiedrichsen/Python/Functional_Fusion/dataset.py:151: RuntimeWarning: invalid value encountered in true_divide
#   r[s,pn,:] = nansum(X1*X2,axis=0)/ \

# %%
plt.figure(figsize=(25,18))
plot_multi_flat(rel,'MNISymC3',
                    grid=(3,5),
                    dtype='func',
                    cscale=[-0.3,0.7],
                    colorbar=False,
                    titles=sess)

# %%
rel,sess = reliability_maps(base_dir,'IBC',subtract_mean=False)
# Out:
# /Users/jdiedrichsen/Python/Functional_Fusion/dataset.py:160: RuntimeWarning: invalid value encountered in true_divide
#   r[s,pn,:] = nansum(X1*X2,axis=0)/ \

# %%
plt.figure(figsize=(25,18))
plot_multi_flat(rel,'MNISymC3',
                    grid=(3,5),
                    dtype='func',
                    cscale=[-0.3,0.7],
                    colorbar=False,
                    titles=sess)

# %% [markdown]
# ## HCP dataset

# %%
rel,sess = reliability_maps(base_dir,'HCP')
# Out:
# /Users/callithrix/Python/Functional_Fusion/dataset.py:154: RuntimeWarning: invalid value encountered in divide
#   r[s,pn,:] = nansum(X1*X2,axis=0)/ \
# /Users/callithrix/Python/Functional_Fusion/dataset.py:219: RuntimeWarning: Mean of empty slice
#   Rel[i,:] = np.nanmean(np.nanmean(r,axis=0),axis=0)

# %%
plt.figure(figsize=(14,8))
plot_multi_flat(rel,'MNISymC3',
                    grid=(1,2),
                    dtype='func',
                    cscale=[-0.3,0.7],
                    colorbar=False,
                    titles=sess)
